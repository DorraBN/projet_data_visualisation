# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df=pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
pd.set_option('display.max_rows',df.shape[0]+1)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
pd.set_option('display.max_rows',10)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Credit_History       50
# Self_Employed        32
# LoanAmount           22
# Dependents           15
# Loan_Amount_Term     14
#                      ..
# Education             0
# ApplicantIncome       0
# CoapplicantIncome     0
# Property_Area         0
# Loan_Status           0
# Length: 13, dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
import seaborn as sb
# %matplotlib inline
sb.countplot(x='LoanAmount',data=df,palette='hls')
# Out:
# <Axes: xlabel='LoanAmount', ylabel='count'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Exemple : Charger un DataFrame à partir d'un fichier CSV
df = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')

# Visualisation de l'histogramme
sns.histplot(data=df, x='LoanAmount', bins=20, kde=True, color='blue')
plt.xlabel('LoanAmount')
plt.ylabel('Credit_History')
plt.title('Histogramme de LoanAmount')
plt.show()

# %%
# Box Plot pour 'ApplicantIncome' et 'CoapplicantIncome'
sns.boxplot(x='variable', y='value', data=pd.melt(df[['ApplicantIncome', 'CoapplicantIncome']]))
plt.xlabel('Income Type')
plt.ylabel('Income Value')
plt.title('Box Plot for ApplicantIncome and CoapplicantIncome')
plt.show()

# %%
# Nuage de points entre 'LoanAmount' et 'ApplicantIncome'
sns.scatterplot(x='ApplicantIncome', y='LoanAmount', data=df, color='green')
plt.xlabel('ApplicantIncome')
plt.ylabel('LoanAmount')
plt.title('Scatter Plot between ApplicantIncome and LoanAmount')
plt.show()

# %%
# Heatmap pour la corrélation entre les variables numériques
correlation_matrix = df[['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
import matplotlib.pyplot as plt

# Supposons que 'df' soit déjà défini

# Sélectionnez la colonne 'Credit_History' pour le Pie Chart
credit_history_counts = df['Credit_History'].value_counts()

# Créez un Pie Chart
labels = credit_history_counts.index
sizes = credit_history_counts.values
colors = ['lightcoral', 'lightskyblue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Assure que le Pie Chart est un cercle.
plt.title('Répartition des catégories de crédit')
plt.show()

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('train_u6lujuX_CVtuZ9i.csv')
sns.boxplot(x='variable', y='value', data=pd.melt(df[['LoanAmount', 'ApplicantIncome', 'CoapplicantIncome']]))
plt.show()

# %%
import matplotlib.pyplot as plt

# Supposons que 'df' soit déjà défini

# Sélectionnez la colonne 'Credit_History' pour le Pie Chart
credit_history_counts = df['Loan_Status'].value_counts()

# Créez un Pie Chart
labels = credit_history_counts.index
sizes = credit_history_counts.values
colors = ['green', 'blue']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Assure que le Pie Chart est un cercle.
plt.title('Répartition des catégories de crédit')
plt.show()

# %%
df.plot(kind='bar', stacked=True)
plt.show()

# %%
df.plot(kind='barh')
plt.show()

# %%
df.plot(x='Loan_Status', y='ApplicantIncome', kind='line')
plt.show()

# %%
sns.violinplot(x='Loan_Status', y='ApplicantIncome', data=df)
plt.show()

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
p = figure(x_range=df['Loan_Status'],title='Diagramme en barres interactif')
p.vbar(x=df['Loan_Status'], top=df['ApplicantIncome'], width=0.9)
show(p)


#x='Loan_Status', y='ApplicantIncome'
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a119d77c-514b-41a2-89bc-b1cd2f69de6e">Loading BokehJS ...</span>
#     </div>
# ERROR:bokeh.core.validation.check:E-1019 (DUPLICATE_FACTORS): FactorRange must specify a unique list of categorical factors for an axis: duplicate factors found: 'Y', 'N'
#   <div id="b46a0745-0f2f-4716-a130-3de5e1455e7e" data-root-id="p1085" style="display: contents;"></div>

# %%
from bokeh.models import HoverTool

p = figure( title='Nuage de points interactif')
p.scatter(x='Loan_Status', y='ApplicantIncome', size='Value', color='Category', source=df)

hover = HoverTool()
hover.tooltips = [('Category', '@Category'), ('Value', '@Value')]
p.add_tools(hover)

show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : fill_color='Category' [no close matches], hatch_color='Category' [no close matches], line_color='Category' [no close matches], size='Value' [no close matches] {renderer: GlyphRenderer(id='p1313', ...)}
#   <div id="d6685ca1-d3ac-46b9-bc65-9490ad092129" data-root-id="p1275" style="display: contents;"></div>
